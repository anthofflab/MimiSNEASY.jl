# %%
using Gadfly

# %%
set_default_plot_size(20cm, 12cm)
# Out:
# 120.0mm

# %%
reload("Iamf.jl")

# %%
include("sneasy.jl")
# Out:
# getsneasy (generic function with 1 method)

# %%
model = getsneasy()
# Out:
# no method convert(Type{ComponentParameters}, radforcpar)
# while loading In[11], in expression starting on line 1
#  in getsneasy at C:\Users\anthoff\source\sneasy.jl\sneasy.jl:48

# %%
run(20,model)
# Out:
# ...
# 1
# radforcpar
# radforcvar
# init radforc
# 2
# doeclimpar
# doeclimvar
# ...
# earth_area not defined
# while loading In[12], in expression starting on line 1
#  in init at C:\Users\anthoff\source\sneasy.jl\doeclim.jl:158

# %%
plot(x=collect(1850:1850+nsteps),y=vardoeclim.temp, 
    Geom.line, 
    Guide.xlabel("year"), Guide.ylabel("°C"), Guide.title("temperature"),
    Theme(grid_color=color("gray")))
# Out:
# D3(200.0,120.0,IOBuffer(Uint8[0x66,0x75,0x6e,0x63,0x74,0x69,0x6f,0x6e,0x20,0x64  …  0x20,0x64,0x72,0x61,0x77,0x0d,0x0a,0x7d,0x0d,0x0a],true,true,true,false,26804,9223372036854775807,26805),0,String[],Bool[],0,3,Dict{Uint64,(Any,Int64)}(),true,false,nothing,true)
# Plot(...)
